# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load data
df=pd.read_csv("Placement_Data_Full_Class.csv")
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.head(8)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6      M  55.00   Others  49.80   Others   Science     67.25
# 6      7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7      8      M  82.00  Central  64.00  Central   Science     66.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No    75.00        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.0
# 5   Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed       NaN
# 6  Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed       NaN
# 7   Sci&Tech    Yes    67.00        Mkt&Fin  62.14      Placed  252000.0

# %%
df.shape
# Out:
# (215, 15)

# %%
df['status']
# Out:
# 0          Placed
# 1          Placed
# 2          Placed
# 3      Not Placed
# 4          Placed
#           ...
# 210        Placed
# 211        Placed
# 212        Placed
# 213        Placed
# 214    Not Placed
# Name: status, Length: 215, dtype: object

# %%
p=df[['degree_p','etest_p']].describe()
p
# Out:
#          degree_p     etest_p
# count  215.000000  215.000000
# mean    66.370186   72.100558
# std      7.358743   13.275956
# min     50.000000   50.000000
# 25%     61.000000   60.000000
# 50%     66.000000   71.000000
# 75%     72.000000   83.500000
# max     91.000000   98.000000

# %%
plt.title("Average Academic Point vs Employbility Test Point")
plt.plot(p.degree_p.iloc[1:8],label='Average Academic Point')
plt.ylabel("Points")
plt.plot(p.etest_p.iloc[1:8],label='Employbility Test Point')
plt.legend()

# %%
df = df.set_index('status')
df.head()
# Out:
#             sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# status
# Placed          1      M  67.00   Others  91.00   Others  Commerce     58.00
# Placed          2      M  79.33  Central  78.33   Others   Science     77.48
# Placed          3      M  65.00  Central  68.00  Central      Arts     64.00
# Not Placed      4      M  56.00  Central  52.00  Central   Science     52.00
# Placed          5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#              degree_t workex  etest_p specialisation  mba_p    salary
# status
# Placed       Sci&Tech     No     55.0         Mkt&HR  58.80  270000.0
# Placed       Sci&Tech    Yes     86.5        Mkt&Fin  66.28  200000.0
# Placed      Comm&Mgmt     No     75.0        Mkt&Fin  57.80  250000.0
# Not Placed   Sci&Tech     No     66.0         Mkt&HR  59.43       NaN
# Placed      Comm&Mgmt     No     96.8        Mkt&Fin  55.50  425000.0

# %%
d=df['specialisation']
d
# Out:
# status
# Placed         Mkt&HR
# Placed        Mkt&Fin
# Placed        Mkt&Fin
# Not Placed     Mkt&HR
# Placed        Mkt&Fin
#                ...
# Placed        Mkt&Fin
# Placed        Mkt&Fin
# Placed        Mkt&Fin
# Placed         Mkt&HR
# Not Placed     Mkt&HR
# Name: specialisation, Length: 215, dtype: object

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'salary'],
#       dtype='object')

# %%
df
# Out:
#             sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# status
# Placed          1      M  67.00   Others  91.00   Others  Commerce     58.00
# Placed          2      M  79.33  Central  78.33   Others   Science     77.48
# Placed          3      M  65.00  Central  68.00  Central      Arts     64.00
# Not Placed      4      M  56.00  Central  52.00  Central   Science     52.00
# Placed          5      M  85.80  Central  73.60  Central  Commerce     73.30
# ...           ...    ...    ...      ...    ...      ...       ...       ...
# Placed        211      M  80.60   Others  82.00   Others  Commerce     77.60
# Placed        212      M  58.00   Others  60.00   Others   Science     72.00
# Placed        213      M  67.00   Others  67.00   Others  Commerce     73.00
# Placed        214      F  74.00   Others  66.00   Others  Commerce     58.00
# Not Placed    215      M  62.00  Central  58.00   Others   Science     53.00
#
#              degree_t workex  etest_p specialisation  mba_p    salary
# status
# Placed       Sci&Tech     No     55.0         Mkt&HR  58.80  270000.0
# Placed       Sci&Tech    Yes     86.5        Mkt&Fin  66.28  200000.0
# Placed      Comm&Mgmt     No     75.0        Mkt&Fin  57.80  250000.0
# Not Placed   Sci&Tech     No     66.0         Mkt&HR  59.43       NaN
# Placed      Comm&Mgmt     No     96.8        Mkt&Fin  55.50  425000.0
# ...               ...    ...      ...            ...    ...       ...
# Placed      Comm&Mgmt     No     91.0        Mkt&Fin  74.49  400000.0
# Placed       Sci&Tech     No     74.0        Mkt&Fin  53.62  275000.0
# Placed      Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72  295000.0
# Placed      Comm&Mgmt     No     70.0         Mkt&HR  60.23  204000.0
# Not Placed  Comm&Mgmt     No     89.0         Mkt&HR  60.22       NaN
#
# [215 rows x 14 columns]

# %%
placed=df.loc['Placed']
placed
# Out:
#         sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# status
# Placed      1      M  67.00   Others  91.00   Others  Commerce     58.00
# Placed      2      M  79.33  Central  78.33   Others   Science     77.48
# Placed      3      M  65.00  Central  68.00  Central      Arts     64.00
# Placed      5      M  85.80  Central  73.60  Central  Commerce     73.30
# Placed      8      M  82.00  Central  64.00  Central   Science     66.00
# ...       ...    ...    ...      ...    ...      ...       ...       ...
# Placed    210      M  62.00  Central  72.00  Central  Commerce     65.00
# Placed    211      M  80.60   Others  82.00   Others  Commerce     77.60
# Placed    212      M  58.00   Others  60.00   Others   Science     72.00
# Placed    213      M  67.00   Others  67.00   Others  Commerce     73.00
# Placed    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#          degree_t workex  etest_p specialisation  mba_p    salary
# status
# Placed   Sci&Tech     No     55.0         Mkt&HR  58.80  270000.0
# Placed   Sci&Tech    Yes     86.5        Mkt&Fin  66.28  200000.0
# Placed  Comm&Mgmt     No     75.0        Mkt&Fin  57.80  250000.0
# Placed  Comm&Mgmt     No     96.8        Mkt&Fin  55.50  425000.0
# Placed   Sci&Tech    Yes     67.0        Mkt&Fin  62.14  252000.0
# ...           ...    ...      ...            ...    ...       ...
# Placed  Comm&Mgmt     No     67.0        Mkt&Fin  56.49  216000.0
# Placed  Comm&Mgmt     No     91.0        Mkt&Fin  74.49  400000.0
# Placed   Sci&Tech     No     74.0        Mkt&Fin  53.62  275000.0
# Placed  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72  295000.0
# Placed  Comm&Mgmt     No     70.0         Mkt&HR  60.23  204000.0
#
# [148 rows x 14 columns]

# %%
print(f'Number of students placed: {placed}')
# Out:
# Number of students placed:         sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# status
# Placed      1      M  67.00   Others  91.00   Others  Commerce     58.00
# Placed      2      M  79.33  Central  78.33   Others   Science     77.48
# Placed      3      M  65.00  Central  68.00  Central      Arts     64.00
# Placed      5      M  85.80  Central  73.60  Central  Commerce     73.30
# Placed      8      M  82.00  Central  64.00  Central   Science     66.00
# ...       ...    ...    ...      ...    ...      ...       ...       ...
# Placed    210      M  62.00  Central  72.00  Central  Commerce     65.00
# Placed    211      M  80.60   Others  82.00   Others  Commerce     77.60
# Placed    212      M  58.00   Others  60.00   Others   Science     72.00
# Placed    213      M  67.00   Others  67.00   Others  Commerce     73.00
# Placed    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#          degree_t workex  etest_p specialisation  mba_p    salary
# status
# Placed   Sci&Tech     No     55.0         Mkt&HR  58.80  270000.0
# Placed   Sci&Tech    Yes     86.5        Mkt&Fin  66.28  200000.0
# Placed  Comm&Mgmt     No     75.0        Mkt&Fin  57.80  250000.0
# Placed  Comm&Mgmt     No     96.8        Mkt&Fin  55.50  425000.0
# Placed   Sci&Tech    Yes     67.0        Mkt&Fin  62.14  252000.0
# ...           ...    ...      ...            ...    ...       ...
# Placed  Comm&Mgmt     No     67.0        Mkt&Fin  56.49  216000.0
# Placed  Comm&Mgmt     No     91.0        Mkt&Fin  74.49  400000.0
# Placed   Sci&Tech     No     74.0        Mkt&Fin  53.62  275000.0
# Placed  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72  295000.0
# Placed  Comm&Mgmt     No     70.0         Mkt&HR  60.23  204000.0
#
# [148 rows x 14 columns]

# %%
plt.figure(figsize=(100,60))
placed.plot(kind='line')
plt.title('Number of Students Placed')
plt.xlabel('Placed')
plt.ylabel('Package')
plt.show()

# %%
gen=df.groupby('gender').value_counts()
print(f'No of students placed and not placed in each gender:\n{gen}\n')
# Out:
# No of students placed and not placed in each gender:
# gender  sl_no  ssc_p  ssc_b    hsc_p  hsc_b    hsc_s     degree_p  degree_t   workex  etest_p  specialisation  mba_p  salary
# F       14     77.00  Central  87.0   Central  Commerce  59.00     Comm&Mgmt  No      68.00    Mkt&Fin         68.63  218000.0    1
#         16     65.00  Central  75.0   Central  Commerce  69.00     Comm&Mgmt  Yes     72.00    Mkt&Fin         64.66  200000.0    1
#         22     79.00  Others   76.0   Others   Commerce  85.00     Comm&Mgmt  No      95.00    Mkt&Fin         69.06  393000.0    1
#         23     69.80  Others   60.8   Others   Science   72.23     Sci&Tech   No      55.53    Mkt&HR          68.81  360000.0    1
#         24     77.40  Others   60.0   Others   Science   64.74     Sci&Tech   Yes     92.00    Mkt&Fin         63.62  300000.0    1
#                                                                                                                                  ..
# M       208    83.33  Central  78.0   Others   Commerce  61.00     Comm&Mgmt  Yes     88.56    Mkt&Fin         71.55  300000.0    1
#         210    62.00  Central  72.0   Central  Commerce  65.00     Comm&Mgmt  No      67.00    Mkt&Fin         56.49  216000.0    1
#         211    80.60  Others   82.0   Others   Commerce  77.60     Comm&Mgmt  No      91.00    Mkt&Fin         74.49  400000.0    1
#         212    58.00  Others   60.0   Others   Science   72.00     Sci&Tech   No      74.00    Mkt&Fin         53.62  275000.0    1
#         213    67.00  Others   67.0   Others   Commerce  73.00     Comm&Mgmt  Yes     59.00    Mkt&Fin         69.72  295000.0    1
# Name: count, Length: 148, dtype: int64

# %%
gen=df.gender.value_counts(normalize=True)*100
plt.title('Gender Distribution in Campus')
lb=['Male','Female']
print(plt.pie(gen,labels=lb,autopct='%.0f%%'))
# Out:
# ([<matplotlib.patches.Wedge object at 0x000001EC437D34D0>, <matplotlib.patches.Wedge object at 0x000001EC437D2A50>], [Text(-0.4886187506849025, 0.9855210380702816, 'Male'), Text(0.48861883684188956, -0.9855209953538682, 'Female')], [Text(-0.26651931855540134, 0.5375569298565172, '65%'), Text(0.26651936555012157, -0.5375569065566553, '35%')])

# %%
plt.title("Statistics of Various Academic Points")
plt.ylabel("Points")
plt.plot(df[['ssc_p','hsc_p','degree_p','mba_p','etest_p']].iloc[0],label='Female')
plt.plot(df[['ssc_p','hsc_p','degree_p','mba_p','etest_p']].iloc[1],label='Male')
plt.legend()

# %%
special=df.groupby('specialisation').value_counts(normalize=True)*100
print(f'Placement Stats Of Different Specialisations:\n{special}\n')
# Out:
# Placement Stats Of Different Specialisations:
# specialisation  sl_no  gender  ssc_p  ssc_b    hsc_p  hsc_b    hsc_s     degree_p  degree_t   workex  etest_p  mba_p  salary
# Mkt&Fin         2      M       79.33  Central  78.33  Others   Science   77.48     Sci&Tech   Yes     86.50    66.28  200000.0    1.052632
#                 3      M       65.00  Central  68.00  Central  Arts      64.00     Comm&Mgmt  No      75.00    57.80  250000.0    1.052632
#                 5      M       85.80  Central  73.60  Central  Commerce  73.30     Comm&Mgmt  No      96.80    55.50  425000.0    1.052632
#                 8      M       82.00  Central  64.00  Central  Science   66.00     Sci&Tech   Yes     67.00    62.14  252000.0    1.052632
#                 9      M       73.00  Central  79.00  Central  Commerce  72.00     Comm&Mgmt  No      91.34    61.29  231000.0    1.052632
#                                                                                                                                     ...
# Mkt&HR          198    F       83.96  Others   53.00  Others   Science   91.00     Sci&Tech   No      59.32    69.71  260000.0    1.886792
#                 200    M       69.00  Others   65.00  Others   Commerce  57.00     Comm&Mgmt  No      73.00    55.80  265000.0    1.886792
#                 203    M       70.00  Central  63.00  Central  Science   66.00     Sci&Tech   No      61.28    60.11  240000.0    1.886792
#                 204    M       55.68  Others   61.33  Others   Commerce  56.87     Comm&Mgmt  No      66.00    58.30  260000.0    1.886792
#                 214    F       74.00  Others   66.00  Others   Commerce  58.00     Comm&Mgmt  No      70.00    60.23  204000.0    1.886792
# Name: proportion, Length: 148, dtype: float64

# %%
p_s=df.loc['Placed']['specialisation']
p_s
spc=df.specialisation.value_counts(normalize=True)*100
spc.plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %%
work_experience=df.groupby('workex').value_counts(normalize=True)*100
print(f'Percentage students placed and not placed based their work experience:\n{work_experience}')
# Out:
# Percentage students placed and not placed based their work experience:
# workex  sl_no  gender  ssc_p  ssc_b    hsc_p  hsc_b    hsc_s     degree_p  degree_t   etest_p  specialisation  mba_p  salary
# No      1      M       67.00  Others   91.0   Others   Commerce  58.0      Sci&Tech   55.00    Mkt&HR          58.80  270000.0    1.190476
#         3      M       65.00  Central  68.0   Central  Arts      64.0      Comm&Mgmt  75.00    Mkt&Fin         57.80  250000.0    1.190476
#         5      M       85.80  Central  73.6   Central  Commerce  73.3      Comm&Mgmt  96.80    Mkt&Fin         55.50  425000.0    1.190476
#         9      M       73.00  Central  79.0   Central  Commerce  72.0      Comm&Mgmt  91.34    Mkt&Fin         61.29  231000.0    1.190476
#         14     F       77.00  Central  87.0   Central  Commerce  59.0      Comm&Mgmt  68.00    Mkt&Fin         68.63  218000.0    1.190476
#                                                                                                                                     ...
# Yes     196    M       66.00  Central  76.0   Central  Commerce  72.0      Comm&Mgmt  84.00    Mkt&HR          58.95  275000.0    1.562500
#         197    M       72.00  Others   63.0   Others   Science   77.5      Sci&Tech   78.00    Mkt&Fin         54.48  250000.0    1.562500
#         205    F       74.00  Others   73.0   Others   Commerce  73.0      Comm&Mgmt  80.00    Mkt&Fin         67.69  210000.0    1.562500
#         208    M       83.33  Central  78.0   Others   Commerce  61.0      Comm&Mgmt  88.56    Mkt&Fin         71.55  300000.0    1.562500
#         213    M       67.00  Others   67.0   Others   Commerce  73.0      Comm&Mgmt  59.00    Mkt&Fin         69.72  295000.0    1.562500
# Name: proportion, Length: 148, dtype: float64

# %%
work=df.workex.value_counts(normalize=True)*100
work.plot(kind='bar',xlabel=['work experience'])
# Out:
# <Axes: xlabel='[work experience]'>

# %%
df.sl_no=df.sl_no.astype(str)
mfe=df[df.specialisation=='Mkt&Fin'].nlargest(10,'etest_p')
plt.plot(mfe.sl_no,mfe.etest_p,"o-c")
plt.title('Top Scores of Employbility test for Marketing & Finance');
plt.xlabel('Id of student');
plt.ylabel('Score');

# %%
plt.figure(figsize=(8, 6))
plt.plot(df.ssc_p)
plt.title('SSC Percentage by Placement Status')
plt.xlabel('Placement Status')
plt.ylabel('SSC Percentage')
plt.show()

# %%
plt.figure(figsize=(7,6))
plt.pie(df['workex'].value_counts(),labels=['yes','no'],startangle=90,autopct='%.1f%%')
plt.title("Pie Chart of Work experience")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data=df, x='salary', bins=20, color='green')
plt.title('Distribution of Salary for Placed Students')
plt.show()

# %%
plt.figure(figsize=(12,6))
df.plot(kind='line',color='blue')
plt.title("Status - Count", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Status - Count')
