# %% [markdown]
# # pandas for analysis
#   - datset
#     - dicctionary of item
#     - list of dictionary
#     - csv file
#     - excel file
#     - json  file
#     - sql connection
#   - creating data
#   - reading data
#   - manipulation data
#   - cleaning data
#   - visualization data

# %%
import pandas as pd

# %%
books ={
    'title':['MOV','the  art of war','ikigai'],
    'author':['shakespear','dun tzu','unknown'],
    'price':[400,1000,300],
}

pd.DataFrame(books)
# Out:
#              title      author  price
# 0              MOV  shakespear    400
# 1  the  art of war     dun tzu   1000
# 2           ikigai     unknown    300

# %%
movies = [
    {'titles':'abcd','director':'ramo','year':'2016'},
    {'titles':'abcd2','director':'ramo','year':'2018'},
]

pd.DataFrame(movies)
# Out:
#   titles director  year
# 0   abcd     ramo  2016
# 1  abcd2     ramo  2018

# %%
pd.read_csv('dummy.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 pd.read_csv('dummy.csv')
#
# File c:\Users\Hp\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Hp\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Hp\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Hp\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Hp\miniconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dummy.csv'

# %%
pd.read_json('dummy.json')

# %%
pd.read_excel(r"C:\Users\Lenovo\Documents\dummy.xlsx")

# %%
url = ('https://raw.githubusercontent.com/digipodium/Datasets/main/regression/kc_house_data.csv')
df = pd.read_csv(url)
df

# %% [markdown]
# first steps after reading the data
# - ` df.head(nrows)`- first n rows
# - ` df.tail(nrows)`- last n rows
# - ` df,info()` - data types,missing values
# - ` df,describe()` - summary statistics
# - ` df.shape()`- number of rows and columns
# - ` df.columns()` - column names

# %%
df.head(2)

# %%
df.tail()

# %%
df.info()

# %%
df.sample(10)

# %%
df.describe() # sumrary statistic  for numrical columns (default)

# %%
df.shape

# %%
print(df.columns.tolist())

# %%
# simple sort
df.sort_values('bedrooms')

# %% [markdown]
# # selecting data in pandas
# - data frame
#   - rows
#     - iloc - index based location
#     - loc - label based location
#   - columns
#     - single column selection
#     - multiple column selection
#     - column selection by data type
#   - conditonal selection
#     - boolean indexing
#     - query method

# %%
df

# %%
# select rows from iloc
df.iloc[100] # idx 100 row
# iloc is worked on the basis of the indexing

# %%
# random 5 rows 
df.iloc[[1,59,100,200,300]]

# %%
# random 5 rows with selected column 
df.iloc[[1,10,20],[9,12,14,7,8]]

# %%
df.iloc[[1,10,20],:5]

# %%
df.iloc[15:50, :10]

# %%
# selecting coloumn baseed index
df.iloc[:,[0,5,10,11]]

# %%
df.iloc[:,:]

# %%
# updating index column
df = df.set_index('id')
df.head()

# %%
df

# %%
df.loc[[291310100,1523300141]]

# %% [markdown]
# ### single column selection
# - dictionary like selection
#    -`dataframe['column_name']`
# - object like selction
#    -`dataframe.column_name`
#
# ### multiple column selection
# -  dictionary like selection\
#    -`dataframe[list_of_column_names]`

# %%
df['price']

# %%
df.columns

# %%
df[['bedrooms','price','sqft_basement']]

# %% [markdown]
# # boolean indexing
# `df['column'] > value`
#
# `df['column'] == value`
#
# `df['column'] != value`

# %%
df[df['price']>1000000]

# %%
df[df['condition']>=5]

# %%
df[df['condition']<=1]

# %%
# 5 starts rated houses + 2 floors 
df[(df['condition']==5) & (df['floors']==2)]

# %%
f1 = df['price']>1000000
f2 = df['condition'] == 5
f3 = df['floors'] == 2
df[f1 & f2 & f3]

# %%
df[f1&f2&f3].reset_index().style.highlight_max(color='blue')

# %%
df[f1&f2&f3].reset_index().style.background_gradient(cmap='GnBu')

# %%
df[f1&f2&f3].reset_index().style.set_properties(color='red',subset=['price'])

# %%
# query 
df.query('price > 2000000')

# %%
df.query('price > 2000000 and condition == 5')

# %%
df.query('price > 2000000 and condition == 5').sort_values('price')

# %% [markdown]
# ## Manipulation and Cleaning data
#   - removing columns
#   - renaming columns
#   - adding columns
#   - changing data types
#   - handling missing values
#   - dropping missing values
#   - using apply() method

# %%
df.columns

# %%
df

# %%
cols_to_drop=[]
df.drop(columns=cols_to_drop)

# %%
df.drop(labels=[21608])
df

# %%
df.drop_duplicates(subset=['date'])#always use a subset

# %%
df.dropna()# remove rows with nan values

# %%
#renaming columns
df.columns

# %%
name_update={
    'lat':'latitude',
    'long':'longitude',
}
df.rename(columns=name_update)

# %%
#dummy column add
df['dummy']='house_price'#repeats same value in all rows
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# 1             2570      7242     2.0           0     0  ...        2170
# 2              770     10000     1.0           0     0  ...         770
# 3             1960      5000     1.0           0     0  ...        1050
# 4             1680      8080     1.0           0     0  ...        1680
# ...            ...       ...     ...         ...   ...  ...         ...
# 21608         1530      1131     3.0           0     0  ...        1530
# 21609         2310      5813     2.0           0     0  ...        2310
# 21610         1020      1350     2.0           0     0  ...        1020
# 21611         1600      2388     2.0           0     0  ...        1600
# 21612         1020      1076     2.0           0     0  ...        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                  0      1955             0    98178  47.5112 -122.257
# 1                400      1951          1991    98125  47.7210 -122.319
# 2                  0      1933             0    98028  47.7379 -122.233
# 3                910      1965             0    98136  47.5208 -122.393
# 4                  0      1987             0    98074  47.6168 -122.045
# ...              ...       ...           ...      ...      ...      ...
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_lot15        dummy  age
# 0            5650  house_price   69
# 1            7639  house_price   73
# 2            8062  house_price   91
# 3            5000  house_price   59
# 4            7503  house_price   37
# ...           ...          ...  ...
# 21608        1509  house_price   15
# 21609        7200  house_price   10
# 21610        2007  house_price   15
# 21611        1287  house_price   20
# 21612        1357  house_price   16
#
# [21613 rows x 22 columns]

# %%
df['age']=2024-df['yr_built']
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_lot15        dummy  \
# 0      1955             0    98178  47.5112 -122.257        5650  house_price
# 1      1951          1991    98125  47.7210 -122.319        7639  house_price
# 2      1933             0    98028  47.7379 -122.233        8062  house_price
# 3      1965             0    98136  47.5208 -122.393        5000  house_price
# 4      1987             0    98074  47.6168 -122.045        7503  house_price
#
#    age
# 0   69
# 1   73
# 2   91
# 3   59
# 4   37
#
# [5 rows x 22 columns]

# %%
df=df.drop(columns='dummy')

# %%
print(df.columns.tolist())
# Out:
# ['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_lot15', 'dummy', 'age']

# %%
columns_seq=[ 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 
            'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 
            'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_lot15', 'id', 'age']
df=df[columns_seq].copy()
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0       1           0     0          3  ...        1180              0
# 1       2           0     0          3  ...        2170            400
# 2       1           0     0          3  ...         770              0
# 3       1           0     0          5  ...        1050            910
# 4       1           0     0          3  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_lot15           id  \
# 0      1955             0    98178  47.5112 -122.257        5650  house_price
# 1      1951          1991    98125  47.7210 -122.319        7639  house_price
# 2      1933             0    98028  47.7379 -122.233        8062  house_price
# 3      1965             0    98136  47.5208 -122.393        5000  house_price
# 4      1987             0    98074  47.6168 -122.045        7503  house_price
#
#   age
# 0  69
# 1  73
# 2  91
# 3  59
# 4  37
#
# [5 rows x 21 columns]

# %%
df.floors.dtype
# Out:
# dtype('float64')

# %%
df.floors=df.floors.astype('int')
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0       1           0     0          3  ...        1180              0
# 1       2           0     0          3  ...        2170            400
# 2       1           0     0          3  ...         770              0
# 3       1           0     0          5  ...        1050            910
# 4       1           0     0          3  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_lot15           id  \
# 0      1955             0    98178  47.5112 -122.257        5650  house_price
# 1      1951          1991    98125  47.7210 -122.319        7639  house_price
# 2      1933             0    98028  47.7379 -122.233        8062  house_price
# 3      1965             0    98136  47.5208 -122.393        5000  house_price
# 4      1987             0    98074  47.6168 -122.045        7503  house_price
#
#   age
# 0  69
# 1  73
# 2  91
# 3  59
# 4  37
#
# [5 rows x 21 columns]

# %%
import numpy as np

# %%
fake_df=pd.DataFrame({
    'A':[1,2,3,4,5],
    'B':[6,7,np.nan,9,10],
    'C':[11,12,13,14,None],
    'D':[16,17,np.nan,20,np.nan]
})
fake_df
# Out:
#    A     B     C     D
# 0  1   6.0  11.0  16.0
# 1  2   7.0  12.0  17.0
# 2  3   NaN  13.0   NaN
# 3  4   9.0  14.0  20.0
# 4  5  10.0   NaN   NaN

# %%
fake_df.dropna()#should not be done
# Out:
#    A    B     C     D
# 0  1  6.0  11.0  16.0
# 1  2  7.0  12.0  17.0
# 3  4  9.0  14.0  20.0

# %%
fake_df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# D    2
# dtype: int64

# %%
fake_df
# Out:
#    A     B     C     D
# 0  1   6.0  11.0  16.0
# 1  2   7.0  12.0  17.0
# 2  3   NaN  13.0   NaN
# 3  4   9.0  14.0  20.0
# 4  5  10.0   NaN   NaN

# %%
fake_df.fillna(8)
# Out:
#    A     B     C     D
# 0  1   6.0  11.0  16.0
# 1  2   7.0  12.0  17.0
# 2  3   8.0  13.0   8.0
# 3  4   9.0  14.0  20.0
# 4  5  10.0   8.0   8.0

# %%
b_mean=fake_df['B'].mean()
fake_df.B=fake_df.B.replace(np.nan,b_mean)
fake_df
# Out:
#    A     B     C     D
# 0  1   6.0  11.0  16.0
# 1  2   7.0  12.0  17.0
# 2  3   8.0  13.0   NaN
# 3  4   9.0  14.0  20.0
# 4  5  10.0   NaN   NaN

# %%
fake_df.D=fake_df.D.fillna(fake_df.D.mean())
fake_df
# Out:
#    A     B     C          D
# 0  1   6.0  11.0  16.000000
# 1  2   7.0  12.0  17.000000
# 2  3   8.0  13.0  17.666667
# 3  4   9.0  14.0  20.000000
# 4  5  10.0   NaN  17.666667
